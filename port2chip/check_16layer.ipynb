# %%
import numpy as np

# %%
z = np.load('style_16layer.npz')
z.keys()
# Out:
# ['conv16.bias',
#  'conv16.weight',
#  'conv15.bias',
#  'conv15.weight',
#  'conv14.bias',
#  'conv14.weight',
#  'conv13.bias',
#  'conv13.weight',
#  'conv12.bias',
#  'conv12.weight',
#  'conv11.bias',
#  'conv11.weight',
#  'conv10.bias',
#  'conv10.weight',
#  'conv9.bias',
#  'conv9.weight',
#  'conv8.bias',
#  'conv8.weight',
#  'conv7.bias',
#  'conv7.weight',
#  'conv6.bias',
#  'conv6.weight',
#  'conv5.bias',
#  'conv5.weight',
#  'conv4.bias',
#  'conv4.weight',
#  'conv3.bias',
#  'conv3.weight',
#  'conv2.bias',
#  'conv2.weight',
#  'conv1.bias',
#  'conv1.weight']

# %%
w_conv1 = z['conv1.weight']
b_conv1 = z['conv1.bias']
w_conv2 = z['conv2.weight']
b_conv2 = z['conv2.bias']
w_conv3 = z['conv3.weight']
b_conv3 = z['conv3.bias']
w_conv4 = z['conv4.weight']
b_conv4 = z['conv4.bias']
w_conv5 = z['conv5.weight']
b_conv5 = z['conv5.bias']
w_conv6 = z['conv6.weight']
b_conv6 = z['conv6.bias']
w_conv7 = z['conv7.weight']
b_conv7 = z['conv7.bias']
w_conv8 = z['conv8.weight']
b_conv8 = z['conv8.bias']
w_conv9 = z['conv9.weight']
b_conv9 = z['conv9.bias']
w_conv10 = z['conv10.weight']
b_conv10 = z['conv10.bias']
w_conv11 = z['conv11.weight']
b_conv11 = z['conv11.bias']
w_conv12 = z['conv12.weight']
b_conv12 = z['conv12.bias']
w_conv13 = z['conv13.weight']
b_conv13 = z['conv13.bias']
w_conv14 = z['conv14.weight']
b_conv14 = z['conv14.bias']
w_conv15 = z['conv15.weight']
b_conv15 = z['conv15.bias']
w_conv16 = z['conv16.weight']
b_conv16 = z['conv16.bias']

# %%
from cs231n.fast_layers import conv_forward_im2col
conv_forward_fast = conv_forward_im2col

# %%
from PIL import Image
im = np.asarray(Image.open('im9.jpg').resize((128, 128)), dtype=np.float32)
im = im[np.newaxis, :, :, :].transpose(0, 3, 1, 2)

# %%
conv_param_x3 = {'stride': 1, 'pad': 1}
conv_param_x1 = {'stride': 1, 'pad': 0}

# %%
x = conv_forward_fast(im, w_conv1, b_conv1, conv_param=conv_param_x3)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv2, b_conv2, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv3, b_conv3, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv4, b_conv4, conv_param=conv_param_x3)
x = np.maximum(x, 0) + im
x = conv_forward_fast(x, w_conv5, b_conv5, conv_param=conv_param_x3)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv6, b_conv6, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv7, b_conv7, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv8, b_conv8, conv_param=conv_param_x3)
x = x + im
x = conv_forward_fast(im, w_conv9, b_conv9, conv_param=conv_param_x3)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv10, b_conv10, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv11, b_conv11, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv12, b_conv12, conv_param=conv_param_x3)
x = np.maximum(x, 0) + im
x = conv_forward_fast(x, w_conv13, b_conv13, conv_param=conv_param_x3)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv14, b_conv14, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv15, b_conv15, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv16, b_conv16, conv_param=conv_param_x3)
oui = np.maximum(x + im, 0)

# %%
ou = oui.reshape((3, 128, 128))
ou = ou.transpose(1, 2, 0)
ou = np.array(ou, dtype=np.uint8)
ou_im = Image.fromarray(ou)
ou_im.save('16layer_im9_after.jpg')

# %%
ou_im
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0xB032AB90>

# %%
# %%timeit
x = conv_forward_fast(im, w_conv1, b_conv1, conv_param=conv_param_x3)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv2, b_conv2, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv3, b_conv3, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv4, b_conv4, conv_param=conv_param_x3)
x = np.maximum(x, 0) + im
x = conv_forward_fast(x, w_conv5, b_conv5, conv_param=conv_param_x3)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv6, b_conv6, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv7, b_conv7, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv8, b_conv8, conv_param=conv_param_x3)
x = x + im
x = conv_forward_fast(im, w_conv9, b_conv9, conv_param=conv_param_x3)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv10, b_conv10, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv11, b_conv11, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv12, b_conv12, conv_param=conv_param_x3)
x = np.maximum(x, 0) + im
x = conv_forward_fast(x, w_conv13, b_conv13, conv_param=conv_param_x3)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv14, b_conv14, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv15, b_conv15, conv_param=conv_param_x1)
x = np.maximum(x, 0)
x = conv_forward_fast(x, w_conv16, b_conv16, conv_param=conv_param_x3)
oui = np.maximum(x + im, 0)
# Out:
# 1 loop, best of 3: 4.73 s per loop

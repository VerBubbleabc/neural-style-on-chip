# %%
from PIL import Image

# %%
Image.open('im4.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB3AF77D0>

# %%
Image.open('im4_after.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB3AF7A70>

# %%
Image.open('im5.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB3AF7850>

# %%
Image.open('im5_after.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB572F310>

# %%
Image.open('im6.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB3AF7D30>

# %%
Image.open('im6_after.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB6464750>

# %%
Image.open('im7.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB0E86170>

# %%
Image.open('im7_after.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB3AF7DB0>

# %%
Image.open('im8.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB0E6CE30>

# %%
Image.open('im8_after.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB0E86390>

# %%
Image.open('im9.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB3AF7BB0>

# %%
Image.open('im9_after.jpg').resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0xB0E6CF50>
